# %% [markdown]
# <a href="https://colab.research.google.com/github/kavita2009/DNA-Scripts/blob/main/Genomics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task: Across all sequences, calculate the percentage of each letter (occurance) for each slot (Slot 1, Slot 2).
#Task #2: Display this as a widget in panel.

import panel as pn
import pandas as pd

pn.extension('perspective')
pn.extension('tabulator')

#1) Calculate percentage of each letter

DNA_chars = ["A", "C", "G", "T"]


patient1Seq = "TGTGCATATG"
patient1SeqList = list = [item1 for item1 in patient1Seq]

patient2Seq = "TGTGACTACC"
patient2SeqList = list = [item2 for item2 in patient2Seq]

patient3Seq = "TGGTATACCA"
patient3SeqList = list = [item3 for item3 in patient3Seq]

patient4Seq = "TGAACATGAA"
patient4SeqList = list = [item4 for item4 in patient4Seq]

patient5Seq = "TGACCAGACT"
patient5SeqList = list = [item5 for item5 in patient5Seq]

index0 = []

index0.append(patient1SeqList[0])
index0.append(patient2SeqList[0])
index0.append(patient3SeqList[0])
index0.append(patient4SeqList[0])
index0.append(patient5SeqList[0])

# print(index0)

index5 = []
index5.append(patient1SeqList[5])
index5.append(patient2SeqList[5])
index5.append(patient3SeqList[5])
index5.append(patient4SeqList[5])
index5.append(patient5SeqList[5])

print(index5)

def calculate_occurance(list_of_sequences):
  global count_A
  global count_T
  global count_C
  global count_G
  count_A = 0
  count_T = 0
  count_C = 0
  count_G = 0
  i=0
  item = 0
  iterating_sequence = list_of_sequences[item]
  for item in range(len(list_of_sequences)):
    for char in iterating_sequence:
      for i in range(len(iterating_sequence)):
        if iterating_sequence[i]=="A":
          count_A+=1
        elif iterating_sequence[i]=="T":
          count_T+=1
        elif iterating_sequence[i]=="C":
          count_C+=1
        elif iterating_sequence[i]=="G":
          count_G+=1
      i+=1
      item+=1
  return count_A, count_T, count_C, count_G
calculate_occurance(list_of_sequences)

def calculate_occurance(index5):
  global count_A
  global count_T
  global count_C
  global count_G
  i = 0
  count_A = 0
  count_T = 0
  count_C = 0
  count_G = 0
  for i in range(len(index5)):
    if index5[i]=="A":
      count_A+=1
    elif index5[i]=="T":
      count_T+=1
    elif index5[i]=="C":
      count_C+=1
    elif index5[i]=="G":
      count_G+=1
    i+=1
  return count_A, count_T, count_C, count_G
calculate_occurance(index5)

def calculate_frequency(index5, count_A, count_T, count_C, count_G):
  global freq_A
  global freq_T
  global freq_C
  global freq_G
  freq_A = format((count_A/(len(index5))), ".0%")
  freq_T = format((count_T/(len(index5))), ".0%")
  freq_C = format((count_C/(len(index5))), ".0%")
  freq_G = format((count_G/(len(index5))), ".0%")
  print(freq_A)
  print(freq_T)
  print(freq_C)
  print(freq_G)

calculate_frequency(index5, count_A, count_T, count_C, count_G)

freq_A = format((count_A/(len(index5))), ".0%")

def create_indexes(index0):
  global index_list
  index_list = []
  i = 0
  for i in range(len(index0)):
    index_list.append(i)
    i+=1
  print(index_list)
create_indexes("AGGTGA")

# for i in range(len(exon_names):



int_list = index_list
df = pd.DataFrame({
    'A': [freq_A],
    'T': [freq_T],
    'C': [freq_C],
    'G': [freq_G],}, index=index_list)
df_widget = pn.widgets.Tabulator(df, buttons={'Print': "<i class='fa fa-print'></i>"})
df_widget

pn.pane.Perspective(df, width=1000)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='63aa95ee-8362-4f4a-a6ca-4c8c4ec6e846'>
#   <div id="cc14379b-c54d-4e27-81e2-66102ad0f503" data-root-id="63aa95ee-8362-4f4a-a6ca-4c8c4ec6e846" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# def create_indexes(sequence):
#   index_list = []
#   i = 0
#   for i in range(len(sequence)):
#     index_list.append(i)
#     i+=1
#   print(index_list)
# create_indexes("AGGTGA")
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# FIND MOST LIKELY AT EACH POINT; recognize two sequences

import pandas as pd
import panel as pn

primers_df = pd.read_excel("Primers.xlsx")
primers_df["Full Sequence"] = primers_df["Full Sequence"].map(lambda x: x.upper())
exon_names = (primers_df["Unnamed: 0"]).tolist()
print(exon_names)
exon_names_input = pn.widgets.Select(name='Exon Name', options=exon_names)
sequence_search_input = pn.widgets.TextInput(name='Text Input', placeholder='Sequence to search for...')
pn.Row(
    pn.Column(exon_names_input, sequence_search_input),
    # pn.bind(find_sequence, exon_names_input, sequence_search_input)
).servable()
# Out:
# ['GCH1_Exon01', 'GCH1_Exon02', 'GCH1_Exon03', 'GCH1_Exon04', 'GCH1_Exon05', 'GCH1_Exon06', 'GCH1_rs10483639', 'GCH1_rs3783641', 'GCH1_rs8007267', 'SPR_Exon 1', 'SPR_Exon 2', 'SPR_Exon 3', 'PTS_Exon 1', 'PTS_Exon 2', 'PTS_Exon 3', 'PTS_Exon 4', 'PTS_Exon 5', 'PTS_Exon 6', 'AKR1B1_Exon 1', 'AKR1B1_Exon 2', 'AKR1B1_Exon 3', 'AKR1B1_Exon 4', 'AKR1B1_Exon 5', 'AKR1B1_Exon 6', 'AKR1B1_Exon 7', 'AKR1B1_Exon 8', 'AKR1B1_Exon 9', 'AKR1B1_Exon 10', 'DHFR_Exon 1', 'DHFR_Exon 2', 'DHFR_Exon 3', 'DHFR_Exon 4', 'DHFR_Exon 5', 'DHFR_Exon 6', 'QDPR_Exon 1', 'QDPR_Exon 2', 'QDPR_Exon 3', 'QDPR_Exon 4', 'QDPR_Exon 5', 'QDPR_Exon 6', 'QDPR_Exon 7', 'QDPR_IVS4+2.6kbA>G', 'PCBD1_Exon 1', 'PCBD1_Exon 2', 'PCBD1_Exon 3', 'PCBD1_Exon 4', 'DBH_Exon 1', 'DBH_Exon 2', 'DBH_Exon 3', 'DBH_Exon 4', 'DBH_Exon 5', 'DBH_Exon 6', 'DBH_Exon 7', 'DBH_Exon 8', 'DBH_Exon 9', 'DBH_Exon 10', 'DBH_Exon 11', 'DBH_Exon 12', 'COMT_Exon 3', 'COMT_Exon 4', 'COMT_Exon 5', 'COMT_Exon 6', 'MAOA_Exon 1', 'MAOA_Exon 2', 'MAOA_Exon 3'
# ...

# %%
# DNA_chars = ["A", "C", "G", "T"]

# list_of_sequences = [patient1SeqList,patient2SeqList,patient3SeqList,patient4SeqList,patient5SeqList]

# patient1Seq = "TGTGCATATG"
# patient1SeqList = list = [item1 for item1 in patient1Seq]

# patient2Seq = "TGTGACTACC"
# patient2SeqList = list = [item2 for item2 in patient2Seq]

# patient3Seq = "TGGTATACCA"
# patient3SeqList = list = [item3 for item3 in patient3Seq]

# patient4Seq = "TGAACATGAA"
# patient4SeqList = list = [item4 for item4 in patient4Seq]

# patient5Seq = "TGACCAGACT"
# patient5SeqList = list = [item5 for item5 in patient5Seq]

# index0 = []

# # index0.append(patient1SeqList[0])
# # index0.append(patient2SeqList[0])
# # index0.append(patient3SeqList[0])
# # index0.append(patient4SeqList[0])
# # index0.append(patient5SeqList[0])

# list_of_indexes = []

# i=0
# for i in range(len(patient1SeqList)):
#   index_creator = ["index", str(i)]
#   print("".join(index_creator))
#   list_of_indexes.append("".join(index_creator))
#   print(type("".join(index_creator)))
#   # if ("".join(index_creator)) in list_of_indexes:
#   #     ("".join(index_creator))==list()
#   #     print(type(("".join(index_creator))))
#   i+=1
# print(list_of_indexes)


# for index in list_of_indexes:
#   index = list()
#   print(index)
# # for alist in list_of_sequences:
# #   index_number_0 = alist[5]
# #   index0.append(index_number_0)
# # print(index0)
